# %%
import torch
import torch.nn as nn
from torchvision import models
from torch.nn.functional import relu
from torchsummary import summary
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
 
import numpy as np

import matplotlib.pyplot as plt

from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
#from skimage import measure
from skimage.metrics import mean_squared_error as mse

import os
import random

# %%
class UNetDenoise(nn.Module):
    #layers definition
    def __init__(self): #constructor for uNetDenoise
        super().__init__() #constructor of parent class to init inherited attributes
        #Encoder portion, with 256x256x3 input. Padding: same for 3x3 convolutions

        #1st downsample layer
        self.conv11 = nn.Conv2d(1,64,kernel_size=3, padding=1) #dataset images are black and white
        self.conv12 = nn.Conv2d(64,64, kernel_size=3, padding=1) #keep padding same, (kernselSize-1)/2
        self.pool1=nn.MaxPool2d(kernel_size=2, stride=2)

        #2nd downsample layer
        self.conv21 = nn.Conv2d(64,128,kernel_size=3, padding=1)
        self.conv22 = nn.Conv2d(128,128,kernel_size=3, padding=1)
        self.pool2=nn.MaxPool2d(kernel_size=2, stride=2)

        #3rd downsample layer
        self.conv31 = nn.Conv2d(128,256,kernel_size=3, padding=1)
        self.conv32 = nn.Conv2d(256,256,kernel_size=3, padding=1)
        self.pool3=nn.MaxPool2d(kernel_size=2, stride=2)

        #4th downsample layer
        self.conv41 = nn.Conv2d(256,512,kernel_size=3, padding=1)
        self.conv42 = nn.Conv2d(512,512,kernel_size=3, padding=1)
        self.pool4=nn.MaxPool2d(kernel_size=2, stride=2)

        #bottle neck
        self.conv51 = nn.Conv2d(512,1024,kernel_size=3, padding=1)
        self.conv52 = nn.Conv2d(1024,1024,kernel_size=3, padding=1)

        #upsample 1
        self.upconv1 = nn.ConvTranspose2d(1024,512,kernel_size=2,stride=2) #1024, but half 
        self.u11 = nn.Conv2d(1024, 512, kernel_size=3, padding=1)
        self.u12 = nn.Conv2d(512, 512, kernel_size=3, padding=1)

        #upsample 2
        self.upconv2 = nn.ConvTranspose2d(512,256,kernel_size=2,stride=2)
        self.u21 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.u22 = nn.Conv2d(256, 256, kernel_size=3, padding=1)

        #upsample 3
        self.upconv3 = nn.ConvTranspose2d(256,128,kernel_size=2,stride=2)
        self.u31 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.u32 = nn.Conv2d(128, 128, kernel_size=3, padding=1)

        #upsample 4
        self.upconv4 = nn.ConvTranspose2d(128,64,kernel_size=2,stride=2)
        self.u41 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.u42 = nn.Conv2d(64, 1, kernel_size=3, padding=1)

    def forward(self, x):
        #encoder forward
        xconv11 = relu(self.conv11(x))
        xconv12 = relu(self.conv12(xconv11))
        xpool1 = self.pool1(xconv12)

        xconv21 = relu(self.conv21(xpool1))
        xconv22 = relu(self.conv22(xconv21))
        xpool2 = self.pool2(xconv22)

        xconv31 = relu(self.conv31(xpool2))
        xconv32 = relu(self.conv32(xconv31))
        xpool3 = self.pool3(xconv32)

        xconv41 = relu(self.conv41(xpool3))
        xconv42 = relu(self.conv42(xconv41))
        xpool4 = self.pool4(xconv42)

        xconv51 = relu(self.conv51(xpool4))
        xconv52 = relu(self.conv52(xconv51))

        #decoder forward 
        xup1 = self.upconv1(xconv52)
        xu11 = torch.cat([xup1, xconv42], dim=1)
        xd11 = relu(self.u11(xu11))
        xd12 = relu(self.u12(xd11))

        xup2 = self.upconv2(xd12)
        xu22 = torch.cat([xup2, xconv32], dim=1)
        xd21 = relu(self.u21(xu22))
        xd22 = relu(self.u22(xd21))

        xup3 = self.upconv3(xd22)
        xu33 = torch.cat([xup3, xconv22], dim=1)
        xd31 = relu(self.u31(xu33))
        xd32 = relu(self.u32(xd31))

        xup4 = self.upconv4(xd32)
        xu44 = torch.cat([xup4, xconv12], dim=1)
        xd41 = relu(self.u41(xu44))
        xd42 = relu(self.u42(xd41))

        return xd42

# %%
model1 = UNetDenoise()
summary(model1, (1, 256, 256))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 256, 256]        640
# ├─Conv2d: 1-2                            [-1, 64, 256, 256]        36,928
# ├─MaxPool2d: 1-3                         [-1, 64, 128, 128]        --
# ├─Conv2d: 1-4                            [-1, 128, 128, 128]       73,856
# ├─Conv2d: 1-5                            [-1, 128, 128, 128]       147,584
# ├─MaxPool2d: 1-6                         [-1, 128, 64, 64]         --
# ├─Conv2d: 1-7                            [-1, 256, 64, 64]         295,168
# ├─Conv2d: 1-8                            [-1, 256, 64, 64]         590,080
# ├─MaxPool2d: 1-9                         [-1, 256, 32, 32]         --
# ├─Conv2d: 1-10                           [-1, 512, 32, 32]         1,180,160
# ├─Conv2d: 1-11                           [-1, 512, 32, 32]         2,359,808
# ├─MaxPool2d: 1-12                        [-1, 512, 16, 16]         --
# ├─Conv2d: 1-13                           [-1, 1024, 16, 16]        4,719,616
# ├─Conv2d: 1-14                           [-1, 1024, 16, 16]        9,438,208
# ├─ConvTranspose2d: 1-15                  [-1, 512, 32, 32]         2,097,664
# ├─Conv2d: 1-16                           [-1, 512, 32, 32]         4,719,104
# ├─Conv2d: 1-17                           [-1, 512, 32, 32]         2,359,808
# ├─ConvTranspose2d: 1-18                  [-1, 256, 64, 64]         524,544
# ├─Conv2d: 1-19                           [-1, 256, 64, 64]         1,179,904
# ├─Conv2d: 1-20                           [-1, 256, 64, 64]         590,080
# ├─ConvTranspose2d: 1-21                  [-1, 128, 128, 128]       131,200
# ├─Conv2d: 1-22                           [-1, 128, 128, 128]       295,040
# ├─Conv2d: 1-23                           [-1, 128, 128, 128]       147,584
# ├─ConvTranspose2d: 1-24                  [-1, 64, 256, 256]        32,832
# ├─Conv2d: 1-25                           [-1, 64, 256, 256]        73,792
# ├─Conv2d: 1-26                           [-1, 1, 256, 256]         577
# ==========================================================================================
# Total params: 30,994,177
# Trainable params: 30,994,177
# Non-trainable params: 0
# Total mult-adds (G): 52.15
# ==========================================================================================
# Input size (MB): 0.25
# Forward/backward pass size (MB): 272.50
# Params size (MB): 118.23
# Estimated Total Size (MB): 390.98
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 256, 256]        640
# ├─Conv2d: 1-2                            [-1, 64, 256, 256]        36,928
# ├─MaxPool2d: 1-3                         [-1, 64, 128, 128]        --
# ├─Conv2d: 1-4                            [-1, 128, 128, 128]       73,856
# ├─Conv2d: 1-5                            [-1, 128, 128, 128]       147,584
# ├─MaxPool2d: 1-6                         [-1, 128, 64, 64]         --
# ├─Conv2d: 1-7                            [-1, 256, 64, 64]         295,168
# ├─Conv2d: 1-8                            [-1, 256, 64, 64]         590,080
# ├─MaxPool2d: 1-9                         [-1, 256, 32, 32]         --
# ├─Conv2d: 1-10                           [-1, 512, 32, 32]         1,180,160
# ├─Conv2d: 1-11                           [-1, 512, 32, 32]         2,359,808
# ├─MaxPool2d: 1-12                        [-1, 512, 16, 16]         --
# ├─Conv2d: 1-13                           [-1, 1024, 16, 16]        4,719,616
# ├─Conv2d: 1-14                           [-1, 1024, 16, 16]        9,438,208
# ├─ConvTranspose2d: 1-15                  [-1, 512, 32, 32]         2,097,664
# ├─Conv2d: 1-16                           [-1, 512, 32, 32]         4,719,104
# ├─Conv2d: 1-17                           [-1, 512, 32, 32]         2,359,808
# ├─ConvTranspose2d: 1-18                  [-1, 256, 64, 64]         524,544
# ├─Conv2d: 1-19                           [-1, 256, 64, 64]         1,179,904
# ├─Conv2d: 1-20                           [-1, 256, 64, 64]         590,080
# ├─ConvTranspose2d: 1-21                  [-1, 128, 128, 128]       131,200
# ├─Conv2d: 1-22                           [-1, 128, 128, 128]       295,040
# ├─Conv2d: 1-23                           [-1, 128, 128, 128]       147,584
# ├─ConvTranspose2d: 1-24                  [-1, 64, 256, 256]        32,832
# ├─Conv2d: 1-25                           [-1, 64, 256, 256]        73,792
# ├─Conv2d: 1-26                           [-1, 1, 256, 256]         577
# ==========================================================================================
# Total params: 30,994,177
# Trainable params: 30,994,177
# Non-trainable params: 0
# Total mult-adds (G): 52.15
# ==========================================================================================
# Input size (MB): 0.25
# Forward/backward pass size (MB): 272.50
# Params size (MB): 118.23
# Estimated Total Size (MB): 390.98
# ==========================================================================================

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") #using gpu
print(device)
# Out:
# cuda:0

# %%
#dataset

# %%
class getDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data = ImageFolder(data_dir, transform=transform) #handles label creation, class names for imgs
        
    def __len__(self): #to let dataloader know len of data
        return len(self.data)
    def __getitem__(self, idx):
        return self.data[idx]
    @property
    def classes(self):
        return self.data.classes

# %%
print(os.getcwd())
# Out:
# C:\Users\hanso\Desktop\projects_desktop\UNetDenoiser

# %%
#image preprocessing function

# %%
preprocess = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((256,256)),
    transforms.ToTensor(),
    #transforms.Lambda(lambda x: x/255) #normalization by div by 255
    #transforms.Normalize(0,1)
])

# %%
print(os.getcwd())
# Out:
# C:\Users\hanso\Desktop\projects_desktop\UNetDenoiser

# %%
train_dir = 'imgDataset/Train400/'
test_dir = 'imgDataset/Test68/'
train_datasetPreSplit =getDataset(train_dir, preprocess)
test_dataset =getDataset(test_dir, preprocess)
train_dataset, val_dataset = random_split(train_datasetPreSplit, [int(0.85*len(train_datasetPreSplit)), len(train_datasetPreSplit)-int(0.85*len(train_datasetPreSplit))])

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
image, label = train_dataset[1]
print(f'MIN: {image.min()}, Max: {image.max()}')
image.shape
# Out:
# MIN: 0.1568627506494522, Max: 0.7490196228027344
# torch.Size([1, 256, 256])

# %%
#training loop

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model1.parameters(), lr=0.001, weight_decay=1e-5)#adam adjustes the learning rate. weight decay for l2 reg

# %%
def psnr(mse, max):
    return 10*np.log10((max**2)/mse)

# %%
dataset_size = 50
batch_size = 32
num_epochs = 200
model1.to(device)
sigma = 15/255 #maybe try 15
psnrMin = float('inf') #to keep track of smallest psnr val for saving weights
patience = 8 #for early stopping
counter = 0 #for early stopping
best_val_loss = float('inf') #for early stopping

# %%
#lists to keep track of losses and metrics at end of an epoch
epochTrainLossList = list()
epochValLossList = list()
epochssimOutputList = list()
epochssimNoisyList = list()
epochpsnrNoisyList= list()
epochpsnrOutputList = list()

# %%
for epoch in range(num_epochs):
    #training
    model1.train()

    
    curBatch = 0
    lossList = list()
    valLossList = list()
    ssimOutputList = list()
    ssimNoisyList = list()
    psnrNoisyList= list()
    psnrOutputList = list()
    
    curTrainloss = 0
    curValloss = 0
    for images, labels in train_loader:
        curBatch += 1
        clean_images = images.to(device)
        #print(clean_images.shape)
        noisy_images = torch.randn_like(clean_images).to(device) 
        #image + noise, set sigma of noise(ex. 10/255), normalize the data. 
        #Then do clean_images+sigma*noisyimages
        #check on validation set
        #test set 
        modelInput = clean_images+sigma*noisy_images   
        optimizer.zero_grad()
        outputs = model1(modelInput)
        # print("outputs shape", outputs.shape)
        # print("clean_imgs shape", clean_images.shape)
        # Compute the loss
        
        loss = criterion(outputs, clean_images)

        #need to compare with clean image
        

        loss.backward()
        optimizer.step()
        lossList.append(loss.item())
        curTrainloss = loss.item()


        #validation
        model1.eval()
        with torch.no_grad():
            for images, labels in val_loader:
                clean_images = images.to(device)
                noisy_images = torch.randn_like(clean_images).to(device) 
                modelInput = clean_images+sigma*noisy_images  
                outputs = model1(modelInput)
                loss = criterion(outputs, clean_images)
                valLossList.append(loss.item())
                curValloss = loss.item()
                
                for anCleanImage, anInput, anOutput in zip(clean_images, modelInput, outputs): #anInput is the nosiy image
                    # Convert tensors to numpy arrays and map values to [0, 1] range
                    anCleanImage = (anCleanImage.cpu().detach().numpy())    #+1 then divide by 2 to make image pixels fall within range of SSIM.
                    anOutput = (anOutput.cpu().detach().numpy())  #don't have to do these 3 lines if normalized by /255
                    anInput = ((anInput.cpu().detach().numpy())).astype(np.float32)

                    #calculating SSIM
                    ssimOutputCalc = ssim(anCleanImage.squeeze(), anOutput.squeeze(), data_range=1)
                    ssimNoisyCalc = ssim(anCleanImage.squeeze(), anInput.squeeze(), data_range=1)
                    ssimOutputList.append(ssimOutputCalc)
                    ssimNoisyList.append(ssimNoisyCalc)

                    #calculating MSE
                    mseNoised = mse(anCleanImage.squeeze(), anInput.squeeze())
                    mseOutput = mse(anCleanImage.squeeze(), anOutput.squeeze())
                    #calc psnr
                    psnrNoised = psnr(mseNoised, 1)
                    psnrOutput=psnr(mseOutput, 1)
                    psnrNoisyList.append(psnrNoised)
                    psnrOutputList.append(psnrOutput)
            print(f" Batch: {curBatch} Of: {len(train_loader)}, Training Loss: {curTrainloss:.4f}, Validation loss: {curValloss:.4f} Avg SSIM of noisy images: {sum(ssimNoisyList)/len(ssimNoisyList):.4f} Avg SSIM of output images: {sum(ssimOutputList)/len(ssimOutputList):.4f} | Avg PSNR of noisy images: {sum(psnrNoisyList)/len(psnrNoisyList):.4f}  Avg PSNR of output images: {sum(psnrOutputList)/len(psnrOutputList):.4f}")



    
    epochTrainLossList.append(sum(lossList)/len(lossList))
    epochValLossList.append(sum(valLossList)/len(valLossList))
    epochssimOutputList.append(sum(ssimOutputList)/len(ssimOutputList))
    epochssimNoisyList.append(sum(ssimNoisyList)/len(ssimNoisyList))
    epochpsnrNoisyList.append(sum(psnrNoisyList)/len(psnrNoisyList))
    epochpsnrOutputList.append(sum(psnrOutputList)/len(psnrOutputList))

    avgEpochPsnr = sum(psnrOutputList)/len(psnrOutputList)
    #updating wieghts based on based psnr
    if avgEpochPsnr < psnrMin:
        torch.save(model1.state_dict(), "denoiserModelBestWeights.pth")
        psnrMin = avgEpochPsnr
    #updating weights every 10 epochs
    if epoch % 10 == 0:
        torch.save(model1.state_dict(), "denoiserWeightsCheckpoint.pth") 
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {sum(lossList)/len(lossList):.4f}, Validation Loss: {sum(valLossList)/len(valLossList):.4f}")

    #early stopping
    val_loss = sum(valLossList)/len(valLossList)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0 
    else:
        counter += 1

    if counter >= patience:
        print("Early stopped at ",(epoch+1)/num_epochs," epochs")
        break
# Out:
#  Batch: 1 Of: 11, Training Loss: 0.1935, Validation loss: 0.1084 Avg SSIM of noisy images: 0.5413 Avg SSIM of output images: 0.3631 | Avg PSNR of noisy images: 24.6070  Avg PSNR of output images: 10.3252
#  Batch: 2 Of: 11, Training Loss: 0.1251, Validation loss: 0.0240 Avg SSIM of noisy images: 0.5414 Avg SSIM of output images: 0.4800 | Avg PSNR of noisy images: 24.6065  Avg PSNR of output images: 13.6725
#  Batch: 3 Of: 11, Training Loss: 0.0260, Validation loss: 0.1320 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.5101 | Avg PSNR of noisy images: 24.6079  Avg PSNR of output images: 12.0503
#  Batch: 4 Of: 11, Training Loss: 0.1291, Validation loss: 0.0280 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.5443 | Avg PSNR of noisy images: 24.6089  Avg PSNR of output images: 13.0256
#  Batch: 5 Of: 11, Training Loss: 0.0261, Validation loss: 0.0152 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.5656 | Avg PSNR of noisy images: 24.6090  Avg PSNR of output images: 14.1717
#  Batch: 6 Of: 11, Training Loss: 0.0171, Validation loss: 0.0269 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.5747 | Avg PSNR of noisy images: 24.6093  Avg PSNR of output images: 14.5053
#  Batch: 7 Of: 11, Training Loss: 0.0332, Validation loss: 0.0304 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.5799 | Avg PSNR of noisy images: 24.6097  Avg PSNR of output images: 14.6550
#  Batch: 8 Of: 11, Training Loss: 0.0412, Validation loss: 0.0291 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.5864 | Avg PSNR of noisy images: 24.6096  Avg PSNR of output images: 14.8786
#  Batch: 9 Of: 11, Training Loss: 0.0277, Validation loss: 0.0193 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.5953 | Avg PSNR of noisy images: 24.6094  Avg PSNR of output images: 15.2801
#  Batch: 10 Of: 11, Training Loss: 0.0194, Validation loss: 0.0088 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.6057 | Avg PSNR of noisy images: 24.6093  Avg PSNR of output images: 15.8407
#  Batch: 11 Of: 11, Training Loss: 0.0088, Validation loss: 0.0124 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.6154 | Avg PSNR of noisy images: 24.6094  Avg PSNR of output images: 16.1356
# Epoch [1/200], Train Loss: 0.0588, Validation Loss: 0.0389
#  Batch: 1 Of: 11, Training Loss: 0.0131, Validation loss: 0.0167 Avg SSIM of noisy images: 0.5418 Avg SSIM of output images: 0.7181 | Avg PSNR of noisy images: 24.6159  Avg PSNR of output images: 17.8665
#  Batch: 2 Of: 11, Training Loss: 0.0157, Validation loss: 0.0126 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7250 | Avg PSNR of noisy images: 24.6125  Avg PSNR of output images: 18.4842
#  Batch: 3 Of: 11, Training Loss: 0.0114, Validation loss: 0.0068 Avg SSIM of noisy images: 0.5417 Avg SSIM of output images: 0.7333 | Avg PSNR of noisy images: 24.6121  Avg PSNR of output images: 19.6859
#  Batch: 4 Of: 11, Training Loss: 0.0067, Validation loss: 0.0050 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7409 | Avg PSNR of noisy images: 24.6110  Avg PSNR of output images: 20.6766
#  Batch: 5 Of: 11, Training Loss: 0.0050, Validation loss: 0.0062 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7469 | Avg PSNR of noisy images: 24.6113  Avg PSNR of output images: 21.0616
#  Batch: 6 Of: 11, Training Loss: 0.0070, Validation loss: 0.0061 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7525 | Avg PSNR of noisy images: 24.6106  Avg PSNR of output images: 21.3645
#  Batch: 7 Of: 11, Training Loss: 0.0057, Validation loss: 0.0033 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7592 | Avg PSNR of noisy images: 24.6108  Avg PSNR of output images: 21.9136
#  Batch: 8 Of: 11, Training Loss: 0.0037, Validation loss: 0.0037 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7652 | Avg PSNR of noisy images: 24.6103  Avg PSNR of output images: 22.1960
#  Batch: 9 Of: 11, Training Loss: 0.0040, Validation loss: 0.0036 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7703 | Avg PSNR of noisy images: 24.6105  Avg PSNR of output images: 22.4218
#  Batch: 10 Of: 11, Training Loss: 0.0044, Validation loss: 0.0028 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7733 | Avg PSNR of noisy images: 24.6104  Avg PSNR of output images: 22.7325
#  Batch: 11 Of: 11, Training Loss: 0.0029, Validation loss: 0.0038 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.7750 | Avg PSNR of noisy images: 24.6099  Avg PSNR of output images: 22.8873
# Epoch [2/200], Train Loss: 0.0072, Validation Loss: 0.0064
#  Batch: 1 Of: 11, Training Loss: 0.0035, Validation loss: 0.0028 Avg SSIM of noisy images: 0.5414 Avg SSIM of output images: 0.8048 | Avg PSNR of noisy images: 24.6077  Avg PSNR of output images: 25.6139
#  Batch: 2 Of: 11, Training Loss: 0.0030, Validation loss: 0.0035 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8083 | Avg PSNR of noisy images: 24.6083  Avg PSNR of output images: 25.3491
#  Batch: 3 Of: 11, Training Loss: 0.0039, Validation loss: 0.0030 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.8092 | Avg PSNR of noisy images: 24.6101  Avg PSNR of output images: 25.3778
#  Batch: 4 Of: 11, Training Loss: 0.0030, Validation loss: 0.0029 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.8090 | Avg PSNR of noisy images: 24.6101  Avg PSNR of output images: 25.4330
#  Batch: 5 Of: 11, Training Loss: 0.0027, Validation loss: 0.0031 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8085 | Avg PSNR of noisy images: 24.6096  Avg PSNR of output images: 25.4014
#  Batch: 6 Of: 11, Training Loss: 0.0030, Validation loss: 0.0031 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8087 | Avg PSNR of noisy images: 24.6088  Avg PSNR of output images: 25.4016
#  Batch: 7 Of: 11, Training Loss: 0.0031, Validation loss: 0.0029 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8099 | Avg PSNR of noisy images: 24.6091  Avg PSNR of output images: 25.4772
#  Batch: 8 Of: 11, Training Loss: 0.0027, Validation loss: 0.0027 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8113 | Avg PSNR of noisy images: 24.6094  Avg PSNR of output images: 25.5485
#  Batch: 9 Of: 11, Training Loss: 0.0027, Validation loss: 0.0025 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8126 | Avg PSNR of noisy images: 24.6091  Avg PSNR of output images: 25.6143
#  Batch: 10 Of: 11, Training Loss: 0.0027, Validation loss: 0.0025 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8137 | Avg PSNR of noisy images: 24.6093  Avg PSNR of output images: 25.6933
#  Batch: 11 Of: 11, Training Loss: 0.0027, Validation loss: 0.0026 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8147 | Avg PSNR of noisy images: 24.6092  Avg PSNR of output images: 25.7630
# Epoch [3/200], Train Loss: 0.0030, Validation Loss: 0.0029
#  Batch: 1 Of: 11, Training Loss: 0.0023, Validation loss: 0.0025 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8248 | Avg PSNR of noisy images: 24.6085  Avg PSNR of output images: 26.4378
#  Batch: 2 Of: 11, Training Loss: 0.0027, Validation loss: 0.0024 Avg SSIM of noisy images: 0.5414 Avg SSIM of output images: 0.8256 | Avg PSNR of noisy images: 24.6056  Avg PSNR of output images: 26.5473
#  Batch: 3 Of: 11, Training Loss: 0.0024, Validation loss: 0.0022 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8264 | Avg PSNR of noisy images: 24.6084  Avg PSNR of output images: 26.6373
#  Batch: 4 Of: 11, Training Loss: 0.0022, Validation loss: 0.0022 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8271 | Avg PSNR of noisy images: 24.6089  Avg PSNR of output images: 26.6733
#  Batch: 5 Of: 11, Training Loss: 0.0025, Validation loss: 0.0022 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8278 | Avg PSNR of noisy images: 24.6086  Avg PSNR of output images: 26.7269
#  Batch: 6 Of: 11, Training Loss: 0.0022, Validation loss: 0.0022 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8287 | Avg PSNR of noisy images: 24.6086  Avg PSNR of output images: 26.7966
#  Batch: 7 Of: 11, Training Loss: 0.0020, Validation loss: 0.0023 Avg SSIM of noisy images: 0.5414 Avg SSIM of output images: 0.8295 | Avg PSNR of noisy images: 24.6083  Avg PSNR of output images: 26.8613
#  Batch: 8 Of: 11, Training Loss: 0.0022, Validation loss: 0.0022 Avg SSIM of noisy images: 0.5414 Avg SSIM of output images: 0.8304 | Avg PSNR of noisy images: 24.6080  Avg PSNR of output images: 26.9271
#  Batch: 9 Of: 11, Training Loss: 0.0020, Validation loss: 0.0020 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8313 | Avg PSNR of noisy images: 24.6086  Avg PSNR of output images: 26.9933
#  Batch: 10 Of: 11, Training Loss: 0.0018, Validation loss: 0.0018 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8321 | Avg PSNR of noisy images: 24.6083  Avg PSNR of output images: 27.0586
#  Batch: 11 Of: 11, Training Loss: 0.0015, Validation loss: 0.0020 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8329 | Avg PSNR of noisy images: 24.6079  Avg PSNR of output images: 27.1220
# Epoch [4/200], Train Loss: 0.0021, Validation Loss: 0.0021
#  Batch: 1 Of: 11, Training Loss: 0.0017, Validation loss: 0.0019 Avg SSIM of noisy images: 0.5413 Avg SSIM of output images: 0.8417 | Avg PSNR of noisy images: 24.6069  Avg PSNR of output images: 27.8814
#  Batch: 2 Of: 11, Training Loss: 0.0018, Validation loss: 0.0018 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8423 | Avg PSNR of noisy images: 24.6092  Avg PSNR of output images: 27.9488
#  Batch: 3 Of: 11, Training Loss: 0.0016, Validation loss: 0.0019 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.8426 | Avg PSNR of noisy images: 24.6100  Avg PSNR of output images: 28.0180
#  Batch: 4 Of: 11, Training Loss: 0.0016, Validation loss: 0.0016 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8428 | Avg PSNR of noisy images: 24.6082  Avg PSNR of output images: 28.0819
#  Batch: 5 Of: 11, Training Loss: 0.0015, Validation loss: 0.0015 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8429 | Avg PSNR of noisy images: 24.6085  Avg PSNR of output images: 28.1487
#  Batch: 6 Of: 11, Training Loss: 0.0015, Validation loss: 0.0016 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8428 | Avg PSNR of noisy images: 24.6084  Avg PSNR of output images: 28.1727
#  Batch: 7 Of: 11, Training Loss: 0.0016, Validation loss: 0.0018 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8427 | Avg PSNR of noisy images: 24.6083  Avg PSNR of output images: 28.1220
#  Batch: 8 Of: 11, Training Loss: 0.0019, Validation loss: 0.0013 Avg SSIM of noisy images: 0.5415 Avg SSIM of output images: 0.8426 | Avg PSNR of noisy images: 24.6082  Avg PSNR of output images: 28.1969
#  Batch: 9 Of: 11, Training Loss: 0.0015, Validation loss: 0.0016 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.8423 | Avg PSNR of noisy images: 24.6087  Avg PSNR of output images: 28.2044
#  Batch: 10 Of: 11, Training Loss: 0.0018, Validation loss: 0.0015 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.8421 | Avg PSNR of noisy images: 24.6087  Avg PSNR of output images: 28.2485
#  Batch: 11 Of: 11, Training Loss: 0.0015, Validation loss: 0.0015 Avg SSIM of noisy images: 0.5416 Avg SSIM of output images: 0.8420 | Avg PSNR of noisy images: 24.6089  Avg PSNR of output images: 28.2706
# Epoch [5/200], Train Loss: 0.0016, Validation Loss: 0.0016
#  Batch: 1 Of: 11, Training Loss: 0.0015, Validation loss: 0.0013 Avg SSIM of noisy images: 0.5413 Avg SSIM of output images: 0.8394 | Avg PSNR of noisy images: 24.6059  Avg PSNR of output images: 28.8657
#  Batch: 2 Of: 11, Training Loss: 0.0013, Validation loss: 0.0016 Avg SSIM of noisy images: 0.5412 Avg SSIM of output images: 0.8389 | Avg PSNR of noisy images: 24.6053  Avg PSNR of output images: 28.7205
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x00000200F93711D0>>
# Traceback (most recent call last):
#   File "C:\Users\hanso\miniconda3\envs\pyTorchEnv\Lib\site-packages\ipykernel\ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 39
#      37 loss.backward()
#      38 optimizer.step()
# ---> 39 lossList.append(loss.item())
#      40 curTrainloss = loss.item()
#      43 #validation
#
# KeyboardInterrupt:

# %%
#plotting PSNR
numPsnrVals = len(epochpsnrOutputList)
plt.plot(range(numPsnrVals), epochpsnrOutputList, label="denoised images")
plt.plot(range(numPsnrVals), epochpsnrNoisyList, label="noisy images")
plt.xlabel('PSNR overtime')
plt.ylabel('PSNR value')
plt.legend()
plt.title('PSNR of Denoised Images (blue) vs PSNR of Noisy Images(orange)')
plt.show()

#plotting SSIM
numSSIMVals = len(epochssimOutputList)
plt.plot(range(numSSIMVals), epochssimOutputList, label="denoised images")
plt.plot(range(numSSIMVals), epochssimNoisyList, label="noisy images")
plt.xlabel('SSIM overtime')
plt.ylabel('SSIM value')
plt.legend()
plt.title('SSIM of Denoised Images (blue) vs SSIM of Noisy Images(orange)')
plt.show()

#plotting Losses
numEpochs = len(epochTrainLossList)
plt.plot(range(numEpochs), epochTrainLossList, label="Training Loss")
plt.plot(range(numEpochs), epochValLossList, label="Validation Loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Plot')
plt.show()

# %%
# final weights save
torch.save(model1.state_dict(), "denoiserFinalWeights.pth")

# %%
#testing model on test set

# %%
model1.eval()
for images, labels in test_loader:
    imagesNoised = images+sigma*torch.randn_like(images) #adding more noise
    #imagesNoised = images
    imageNoised=imagesNoised.to(device)
    with torch.no_grad():
        denoised_imgs = model1(imageNoised)
    
    # Convert tensors to numpy arrays and move to CPU
    imageNoised = imageNoised.cpu().numpy()
    denoised_imgs = denoised_imgs.cpu().numpy()
    clean_imgs = images.cpu().numpy()

    num_imgs = len(imageNoised)
    fig, axes = plt.subplots(num_imgs, 3, figsize=(7, num_imgs * 6))
    
    for i in range(num_imgs):
        axes[i, 0].imshow(clean_imgs[i].squeeze(), cmap='gray')
        axes[i, 0].set_title('Clean Test Image Input')
        #axes[i, 0].axis('off')
        
        axes[i, 1].imshow(imageNoised[i].squeeze(), cmap='gray')
        axes[i, 1].set_title('Image with added Noise')
       # axes[i, 1].axis('off')
        ssimCalcNoised = ssim(clean_imgs[i].squeeze(), imageNoised[i].squeeze(), data_range=1)
        mseOutNoised = mse(imageNoised[i].squeeze(), clean_imgs[i].squeeze()) #psnr between test(noisy) image and denoised
        psnrOutNoised = psnr(mseOutNoised, 1)
        axes[i, 1].set_xlabel(f'PSNR: {psnrOutNoised:.4f}, SSIM: {ssimCalcNoised:.4f}')
        
        # Plot the denoised output image
        axes[i, 2].imshow(denoised_imgs[i].squeeze(), cmap='gray')
        axes[i, 2].set_title('Denoised Output Image')
        ssimCalcDenoised = ssim(clean_imgs[i].squeeze(), denoised_imgs[i].squeeze(), data_range=1)
        mseOutDenoised = mse(denoised_imgs[i].squeeze(), clean_imgs[i].squeeze()) #psnr between test(noisy) image and denoised
        psnrOutDenoised = psnr(mseOutDenoised, 1)
        axes[i, 2].set_xlabel(f'PSNR: {psnrOutDenoised:.4f}, SSIM: {ssimCalcDenoised:.4f}')
        #axes[i, 2].axis('off')
    plt.tight_layout()
    plt.show()
    break;
